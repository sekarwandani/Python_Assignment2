# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv(r'C:\Users\sekarw\Documents\mbkm materi\assigment1\nyc-rolling-sales.csv')

                  
print ('Data read into a pandas dataframe!')
# Out:
# Data read into a pandas dataframe!

# %%
# Menampilkan dataframe
df.head(5)
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD
# 0           4        1  ALPHABET CITY  \
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392  \
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...
# 0    6                                  C2            153 AVENUE B  ...  \
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# ...

# %%
# Menampilkan jumlah baris dan kolom dalam dataframe
df.shape
# Out:
# (84548, 22)

# %%
# Menampilkan tipe data masing-masing kolom
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      84548 non-null  int64
#  1   BOROUGH                         84548 non-null  int64
#  2   NEIGHBORHOOD                    84548 non-null  object
#  3   BUILDING CLASS CATEGORY         84548 non-null  object
#  4   TAX CLASS AT PRESENT            84548 non-null  object
#  5   BLOCK                           84548 non-null  int64
#  6   LOT                             84548 non-null  int64
#  7   EASE-MENT                       84548 non-null  object
#  8   BUILDING CLASS AT PRESENT       84548 non-null  object
#  9   ADDRESS                         84548 non-null  object
#  10  APARTMENT NUMBER                84548 non-null  object
#  11  ZIP CODE                        84548 non-null  int64
# ...

# %%
# menghapus kolom unnamed:0 dan ease-ment
df.drop(['Unnamed: 0','EASE-MENT'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY
# 0        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS               \
# 1        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT
# 0                   2A    392    6                        C2  \
# 1                    2    399   26                        C7
# 2                    2    399   39                        C7
# 3                   2B    402   21                        C4
# 4                   2A    404   55                        C2
#
#                   ADDRESS APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS
# 0            153 AVENUE B                      10009                  5  \
# 1   234 EAST 4TH   STREET                      10009                 28
# ...

# %%
# Mengubah tipe data pada kolom redidential units, commercial, total units, land square feet, gross square feet, dan sale price  menjadi data numeric
num = ["RESIDENTIAL UNITS","COMMERCIAL UNITS","TOTAL UNITS", "LAND SQUARE FEET" , "GROSS SQUARE FEET","SALE PRICE" ]

for col in num: 
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
# mengubah kolom data sale date menjadi datatime
df['SALE DATE'] = pd.to_datetime(df['SALE DATE'], errors='coerce')

# %%
# mengubah tipe data menjadi kategorikal
kateg = ['NEIGHBORHOOD', 'BUILDING CLASS CATEGORY', 'TAX CLASS AT PRESENT', 'BUILDING CLASS AT PRESENT', 'BUILDING CLASS AT TIME OF SALE', 'TAX CLASS AT TIME OF SALE']
for col in kateg:
    df[col] = df[col].astype('category')

# %%
#cek missing value
missing = df.isnull().sum()

# %%
#cek duplicated
df.duplicated().sum()
# Out:
# 765

# %%
# hapus data duplicated
df.drop_duplicates(inplace=True)

print(sum(df.duplicated()))
# Out:
# 0

# %%
#deskriptif
df[df['RESIDENTIAL UNITS']==0].describe().transpose()
# Out:
#                      count                           mean
# BOROUGH            24546.0                       2.542084  \
# BLOCK              24546.0                    3355.267172
# LOT                24546.0                     283.943412
# ZIP CODE           24546.0                   10321.514626
# RESIDENTIAL UNITS  24546.0                            0.0
# COMMERCIAL UNITS   24546.0                       0.459382
# TOTAL UNITS        24546.0                        0.56335
# LAND SQUARE FEET    9503.0                    7416.797432
# GROSS SQUARE FEET   8360.0                    7427.345813
# YEAR BUILT         24546.0                    1675.525788
# SALE PRICE         20855.0                 1632256.534692
# SALE DATE            24546  2017-03-02 05:54:13.287704576
#
#                                    min                  25%
# BOROUGH                            1.0                  1.0  \
# BLOCK                              1.0               1158.0
# ...

# %%
rep_mode = ['TAX CLASS AT PRESENT','BUILDING CLASS AT PRESENT']
for col1 in rep_mode:
    df[col1].fillna(df[col1].mode(), inplace=True)

#Tipe data numeric
df["LAND SQUARE FEET"]=df["LAND SQUARE FEET"].fillna(df["LAND SQUARE FEET"].median())
df["GROSS SQUARE FEET"]=df["GROSS SQUARE FEET"].fillna(df["GROSS SQUARE FEET"].median())
df["SALE PRICE"]=df["SALE PRICE"].fillna(df["SALE PRICE"].median())

# %%
# menghapus data duplikat pada kolom YEAR BUILT
years = df["YEAR BUILT"].drop_duplicates()
years
# Out:
# 0        1900
# 3        1913
# 6        1920
# 10       1910
# 11       2009
#          ...
# 33557    1871
# 39533    1893
# 44615    1865
# 45042    1882
# 81875    1680
# Name: YEAR BUILT, Length: 158, dtype: int64

# %%
#Menghitung nilai 0 pada kolom YEAR BUILT, TOTAL UNIT, SALE PRICE
print("Nilai 0 pada YEAR BUILT: ",df[df['YEAR BUILT']==0]['YEAR BUILT'].count())
print("Nilai 0 pada TOTAL UNIT: ",df[df['TOTAL UNITS']==0]['TOTAL UNITS'].count())
print("Nilai 0 pada SALE PRICE: ",df[df['SALE PRICE']==0]['SALE PRICE'].count())
# Out:
# Nilai 0 pada YEAR BUILT:  6885
# Nilai 0 pada TOTAL UNIT:  19677
# Nilai 0 pada SALE PRICE:  10012

# %%
#Menghapus nilai 0 pada kolom YEAR BUILT, TOTAL UNIT, SALE PRICE
df['YEAR BUILT'].replace(0, np.nan, inplace=True)
df['TOTAL UNITS'].replace(0, np.nan, inplace=True)
df['SALE PRICE'].replace(0, np.nan, inplace=True)

# %%
#Pengecekan nilai 0 pada kolom YEAR BUILT, TOTAL UNIT, SALE PRICE 
print("Nilai 0 pada YEAR BUILT: ",df[df['YEAR BUILT']==0]['YEAR BUILT'].count())
print("Nilai 0 pada TOTAL UNIT: ",df[df['TOTAL UNITS']==0]['TOTAL UNITS'].count())
print("Nilai 0 pada SALE PRICE: ",df[df['SALE PRICE']==0]['SALE PRICE'].count())
# Out:
# Nilai 0 pada YEAR BUILT:  0
# Nilai 0 pada TOTAL UNIT:  0
# Nilai 0 pada SALE PRICE:  0

# %%
df = df[(df['SALE PRICE'] > 100000) & (df['SALE PRICE'] < 800000)]

# %%
# Melakukan encode pada kolom BOROUGH
df['BOROUGH']= df['BOROUGH'].map({1:'Manhattan', 2:'Bronx', 3: 'Brooklyn', 4:'Queens',5:'Staten Island'})
df.head()
# Out:
#      BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY
# 1  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS               \
# 2  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 5  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 7  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 8  Manhattan  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT
# 1                    2    399   26                        C7  \
# 2                    2    399   39                        C7
# 5                    2    405   16                        C4
# 7                    2    407   18                        C7
# 8                    2    379   34                        D5
#
#                   ADDRESS APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS
# 1   234 EAST 4TH   STREET                      10009                 28  \
# ...

# %% [markdown]
# # Central Tendency

# %% [markdown]
# * Mean

# %%
# menghitung Rata-rata setiap wilayah
rata_rata=df['SALE PRICE'].groupby(df['BOROUGH']).value_counts()
# Graded-Funtion Begin (~1 Lines)
print(rata_rata)
# Graded-Funtion End
print('mean',rata_rata.mean())
# Out:
# BOROUGH        SALE PRICE
# Bronx          500000.0      61
#                300000.0      55
#                400000.0      54
#                550000.0      49
#                450000.0      48
#                              ..
# Staten Island  217500.0       1
#                217055.0       1
#                456198.0       1
#                216996.0       1
#                402500.0       1
# Name: count, Length: 7151, dtype: int64
# mean 6.831911620752343

# %% [markdown]
# * Median

# %%
# Menghitung Nilai tengah
nilai_tengah= df['SALE PRICE'].groupby(df['BOROUGH']).value_counts()

print(nilai_tengah.describe())

print('median',nilai_tengah.median())
# Out:
# count    7151.000000
# mean        6.831912
# std       109.933222
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max      8141.000000
# Name: count, dtype: float64
# median 1.0

# %% [markdown]
# * Modus

# %%
# Menghitung modus

#modus = mode(data)
modus = df['SALE PRICE'].groupby(df['BOROUGH']).value_counts()
modus.mode()
# Out:
# 0    1
# Name: count, dtype: int64

# %% [markdown]
# * Range

# %%
# Menghitung Range
Range = df['SALE PRICE'].groupby(df['BOROUGH']).value_counts()
Range=Range.describe()
range = Range['max']-Range['min']
range
# Out:
# 8140.0

# %% [markdown]
# * Variance

# %%
# Menghitung Variance
varians = df['SALE PRICE'].groupby(df['BOROUGH']).value_counts()
varians.var()
# Out:
# 12085.313280806735

# %% [markdown]
# * Standard Deviation

# %%
standar_deviasi = df['SALE PRICE'].groupby(df['BOROUGH']).value_counts()

standar_deviasi.std()
# Out:
# 109.9332219158828

# %%
#memeriksa 10 properti teratas dalam hal harga jual
df.nlargest(10,'SALE PRICE')
# Out:
#          BOROUGH             NEIGHBORHOOD
# 15199  Manhattan  UPPER WEST SIDE (59-79)  \
# 68272     Queens               OZONE PARK
# 5443   Manhattan           HARLEM-CENTRAL
# 33390   Brooklyn             CLINTON HILL
# 41603   Brooklyn                  MADISON
# 45648   Brooklyn         PROSPECT HEIGHTS
# 56306     Queens           FLUSHING-NORTH
# 30895   Brooklyn         BROOKLYN HEIGHTS
# 58493     Queens           FLUSHING-NORTH
# 58     Manhattan            ALPHABET CITY
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT
# 15199  10 COOPS - ELEVATOR APARTMENTS                                 2  \
# 68272  02 TWO FAMILY DWELLINGS                                        1
# 5443   13 CONDOS - ELEVATOR APARTMENTS                                2
# 33390  13 CONDOS - ELEVATOR APARTMENTS                                2
# 41603  13 CONDOS - ELEVATOR APARTMENTS                                2
# ...

# %%
# import library yang dibutuhkan
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy import stats

# %%
from IPython.display import Math, Latex
# for displaying images
from IPython.core.display import Image
# import seaborn

# %%
#distribusi pada kolom sale price
plt.figure(figsize=(20,15))
ax = sns.distplot(df['SALE PRICE'],
                  kde=True,
                  bins=100,
                  color='skyblue',
                  hist_kws={"linewidth":10, 'alpha':1})
ax.set(xlabel='sale price', ylabel='frequency')
plt.xlabel('Sale Price', fontsize = 20)
plt.ylabel('Frequency', fontsize = 20)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('Distribution of the Sale Price values', fontsize = 20)
plt.show()
# Out:
# C:\Users\sekarw\AppData\Local\Temp\ipykernel_54176\32566817.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df['SALE PRICE'],

# %%
#distribusi tahun dibangun
sns.distplot(df['YEAR BUILT'], bins=20)
plt.show()
# Out:
# C:\Users\sekarw\AppData\Local\Temp\ipykernel_54176\2373967765.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['YEAR BUILT'], bins=20)

# %%
# Distribution Probability of Sale Price in Bronx
plt.figure(figsize = (10,6))
distribusi_sp = df.groupby("BOROUGH")
n = distribusi_sp.get_group('Brooklyn')


ax = sns.distplot(n['SALE PRICE'],
                  kde=True,
                  bins=15,
                  color='orange',
                  hist_kws={"linewidth": 15,'alpha': 0.35})

ax.set(xlabel='Price', 
       ylabel='Probability of Occurence', 
       title='Distribution of Sale Price in Bronx')
# Out:
# C:\Users\sekarw\AppData\Local\Temp\ipykernel_54176\2113903657.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(n['SALE PRICE'],
# [Text(0.5, 0, 'Price'),
#  Text(0, 0.5, 'Probability of Occurence'),
#  Text(0.5, 1.0, 'Distribution of Sale Price in Bronx')]

# %%
# Distribution of Sale Price in Brooklyn
plt.figure(figsize=(10,6))
df_1 = df.groupby("BOROUGH")
n = df_1.get_group('Brooklyn')


ax = sns.distplot(n['SALE PRICE'],
                  kde=True,
                  bins= 20,
                  color='purple',
                  hist_kws={"linewidth": 15,'alpha':0.55})

ax.set(xlabel='Price', 
       ylabel='Probability of Occurence', 
       title='Distribution of Sale Price in Brooklyn')
# Out:
# C:\Users\sekarw\AppData\Local\Temp\ipykernel_54176\1954661096.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(n['SALE PRICE'],
# [Text(0.5, 0, 'Price'),
#  Text(0, 0.5, 'Probability of Occurence'),
#  Text(0.5, 1.0, 'Distribution of Sale Price in Brooklyn')]

# %%
#Mengambil log pada kolom sale price
plt.figure(figsize=(10,6))
sns.distplot(np.log(df['SALE PRICE'].values), kde=True)
plt.xlabel('Sale Price', fontsize = 20)
plt.ylabel('Frequency', fontsize = 20)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('Distribution of the Sale Price values', fontsize = 20)
plt.show()
# Out:
# C:\Users\sekarw\AppData\Local\Temp\ipykernel_54176\3643450906.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['SALE PRICE'].values), kde=True)
